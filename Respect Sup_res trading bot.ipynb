# %%
import pandas as pd
import datetime as dt
import numpy as np
import requests
import json
import pickle
from dateutil.parser import *
import time
import logging
import os
import pytz
import pprint

# %%
API_KEY = 'x'
ACCOUNT_ID = 'x'
OANDA_URL = 'https://api-fxpractice.oanda.com/v3'

SECURE_HEADER = {
    'Authorization': f'Bearer {API_KEY}',
    'Content-Type': 'application/json'
}

# %%
class OandaTrade():
    def __init__(self,oanda_ob):
        
        self.unrealizedPL = float(oanda_ob['unrealizedPL'])
        self.currentUnits = int(oanda_ob['currentUnits'])
        self.trade_id= int(oanda_ob['id'])
        self.openTime = parse(oanda_ob['openTime'])
        self.instrument = oanda_ob['instrument']
        
    def __repr__(self):
        return str(vars(self))

    @classmethod
    def TradeFromAPI(cls, api_object):
        return OandaTrade(api_object)

# %%
class OandaAPI():

    def __init__(self):
        self.session = requests.Session()    
    
    #connection link to server
    def make_request(self, url, params={}, added_headers=None, verb='get', data=None, code_ok=200):

        headers = SECURE_HEADER

        if added_headers is not None:   
            for k in added_headers.keys():
                headers[k] = added_headers[k]
                
        try:
            response = None
            if verb == 'post':
                response = self.session.post(url,params=params,headers=headers,data=data)
            elif verb == 'put':
                response = self.session.put(url,params=params,headers=headers,data=data)
            else:
                response = self.session.get(url,params=params,headers=headers,data=data)

            status_code = response.status_code

            if status_code == code_ok:
                json_response = response.json()
                return status_code, json_response
            
            else:
                return status_code, None  
        except:
            print('make_request error 1')
            try:
                response = None
                if verb == 'post':
                    response = self.session.post(url,params=params,headers=headers,data=data)
                elif verb == 'put':
                    response = self.session.put(url,params=params,headers=headers,data=data)
                else:
                    response = self.session.get(url,params=params,headers=headers,data=data)
                status_code = response.status_code
                
                if status_code == code_ok:
                    json_response = response.json()
                    return status_code, json_response
            
                else:
                    return status_code, None  
            except:
                print("make_request error 2")
                return 400, None   
    
    #get instruments list
    def fetch_instruments(self):
        url = f"{OANDA_URL}/accounts/{ACCOUNT_ID}/instruments"
        status_code, data = self.make_request(url)
        return status_code, data
    
    #change instruments list to df
    def get_instruments_df(self):
        status_code, data = self.fetch_instruments()
        if status_code == 200:
            df = pd.DataFrame.from_dict(data['instruments'])
            return df[['name', 'type', 'displayName', 'pipLocation', 'marginRate']]
        else:
            return None
    
    #get candles from server and change to df with candles_to_df
    def fetch_candles(self, pair_name, count = 32,granularity="M1"):
        url = f"{OANDA_URL}/instruments/{pair_name}/candles"

        params = dict(
            granularity = granularity,
            price = "MBA"
        )
        
        params['count'] = count
        
        
        status_code, data = self.make_request(url, params=params)

        if status_code != 200:
            return status_code, None

        return status_code, OandaAPI.candles_to_df(data['candles'])
    
    #get last candle time
    def last_complete_candle(self,pair_name,granularity ='M1'):
        code, df = self.fetch_candles(pair_name,granularity = granularity)
        if df is None or df.shape[0]==0:
            return None
        return df.iloc[-1].time
    
    
    def place_trade(self,pair,units,take_profit = None, stop_loss = None):
        url = f"{OANDA_URL}/accounts/{ACCOUNT_ID}/orders"

        data = {
            "order": {
                "units": units,
                "instrument": pair,
                "timeInForce": "FOK",
                "type": "MARKET",
                "positionFill": "DEFAULT"
            }
        }
        
        #make a trade with the data above
        status_code, json_data = self.make_request(url,verb = 'post',data = json.dumps(data), code_ok = 201)
        
        if status_code!=201:
            return None
        
        trade_id = None
        ok1 = True
        ok2= True
        
        #get trade id after making trade
        if 'orderFillTransaction' in json_data and 'tradeOpened' in json_data['orderFillTransaction']:
            trade_id =  int(json_data['orderFillTransaction']['tradeOpened']['tradeID'])
            price_str =  json_data['orderFillTransaction']['price']
            units = int(json_data['orderFillTransaction']['tradeOpened']['units'])
            print('trade done')
        
        #runs function to create tp after getting trade_id
        if take_profit is not None:
            if units>0:
                if (self.set_sl_tp(float(price_str)+take_profit, 'TAKE_PROFIT', trade_id) ==False):
                    ok1= False
            if units<0:
                if (self.set_sl_tp(float(price_str)-take_profit, 'TAKE_PROFIT', trade_id) ==False):
                    ok1= False                   
        if stop_loss is not None:
            if units>0:
                if (self.set_sl_tp(float(price_str)-take_profit, 'STOP_LOSS', trade_id) == False):
                    ok2=False
            if units<0:
                if (self.set_sl_tp(float(price_str)+take_profit, 'STOP_LOSS', trade_id) == False):
                    ok2=False
        return trade_id,ok1,ok2
                
    #function to make tp trades
    def set_sl_tp(self,price,order_type,trade_id):
        url = f"{OANDA_URL}/accounts/{ACCOUNT_ID}/orders"
        data = {
            "order": {
                "timeInForce": "GTC",
                "price": str(price), 
                "type": order_type,
                "tradeID": str(trade_id)
            }
        }
        
        status_code, json_data = self.make_request(url, verb='post', data=json.dumps(data), code_ok=201)

        if status_code != 201:
            data = {
            "order": {
                "timeInForce": "GTC",
                "price": str(round(price,3)), 
                "type": order_type,
                "tradeID": str(trade_id)
            }
        }
            status_code, json_data = self.make_request(url, verb='post', data=json.dumps(data), code_ok=201)
            
            if status_code != 201:
                print (status_code)
                return False
        return True
    
    #run request to close trade
    def close_trade(self,trade_id):
        url = f"{OANDA_URL}/accounts/{ACCOUNT_ID}/trades/{trade_id}/close"
        status_code, json_data = self.make_request(url, verb='put', code_ok=200)
        if status_code !=200:
            print(status_code)
            return False
        print ('close trade')
        return True
    
    #returns all open trades as OandaTrade object
    def open_trades(self):
        url = f"{OANDA_URL}/accounts/{ACCOUNT_ID}/openTrades"
        status_code, data = self.make_request(url)
        
        if status_code !=200:
            return [], False
        #could be that the code work but we dont have any open trades. will still return false. so return true as long as 
        #'trades' not in data
        if 'trades' not in data:
            return [], True
        
        trades = [OandaTrade.TradeFromAPI(x) for x in data['trades']]
        
        return trades,True
    
    #change candles from fetch candles to a dataframe
    @classmethod
    def candles_to_df(cls, json_data):
        prices = ['mid', 'bid', 'ask']
        ohlc = ['o', 'h', 'l', 'c']

        our_data = []
        for candle in json_data:
            if candle['complete'] == False:
                continue
            new_dict = {}
            new_dict['time'] = candle['time']
            new_dict['volume'] = candle['volume']
            for price in prices:
                for oh in ohlc:
                    new_dict[f"{price}_{oh}"] = float(candle[price][oh])
            our_data.append(new_dict)
        df = pd.DataFrame.from_dict(our_data)
        df["time"] = [parse(x) for x in df.time]
        return df

if __name__ == "__main__":
    api = OandaAPI()
    #res, df = api.fetch_candles("EUR_USD")
    #print(df)
    #print(api.last_complete_candle('EUR_USD'))
    trades, ok = api.open_trades()
    if ok == True:
         [print(t) for t in trades]
         print(ok)
#api=OandaAPI()

#api.set_sl_tp(89.54000001,'STOP_LOSS','248')
# Out:
# {'unrealizedPL': -1.3755, 'currentUnits': 1000, 'trade_id': 931, 'openTime': datetime.datetime(2021, 6, 25, 1, 1, 11, 549545, tzinfo=tzutc()), 'instrument': 'AUD_JPY'}
# True

# %%
def time_utc():
    return dt.datetime.utcnow().replace(tzinfo=dt.timezone.utc)

def get_utc_dt_from_string(date_str):
    d = parse(date_str)
    return d.replace(tzinfo=dt.timezone.utc)

# %%
#create a logging file

LOG_FORMAT= '%(asctime)s %(message)s'
DEFAULT_LEVEL = logging.DEBUG

#w is overwrite, a is append. this creates a new log and it logs stuff in the logger file
class LogWrapper():
    def __init__(self, name, mode="w"):
        self.create_directory()       
        self.filename = './logs/' + name + '.log'
        self.logger = logging.getLogger(name)
        self.logger.setLevel(DEFAULT_LEVEL)
        
        file_handler = logging.FileHandler(self.filename,mode=mode)
        formatter = logging.Formatter(LOG_FORMAT,datefmt='%Y-%M-%D %H:%M:%S')
        file_handler.setFormatter(formatter)
        self.logger.addHandler(file_handler)
        self.logger.info('LogWrapper init() '+self.filename)

    def create_directory(self):
        path = './logs'
        if not os.path.exists(path):
            os.makedirs(path)

            
if __name__ == "__main__":
    #creates log file called test
    log = LogWrapper(name="Test")
    #adds to log file
    log.logger.debug("HELLO")

# %%
###create json file
data = {
    'GBP_JPY' :  { "pair" :  'GBP_JPY', "units": 1000, "pip": 0.01},
    'GBP_AUD' :  { "pair" :  'GBP_AUD', "units": 1000, "pip": 0.0001},
    'GBP_USD' :  { "pair" :  'GBP_USD', "units": 1000, "pip": 0.0001},
    'USD_CAD' :  { "pair" :  'USD_CAD', "units": 1000, "pip": 0.0001},
    'USD_JPY' :  { "pair" :  'USD_JPY', "units": 1000, "pip": 0.01},
    #'AUD_JPY' :  { "pair" :  'AUD_JPY', "units": 1000, "pip": 0.01},
    #'AUD_CAD' :  { "pair" :  'AUD_CAD', "units": 1000, "pip": 0.0001},
    #'EUR_USD' :  { "pair" :  'EUR_USD', "units": 1000, "pip": 0.0001},
    #'EUR_JPY' :  { "pair" :  'EUR_JPY', "units": 1000, "pip": 0.01},
    #'EUR_AUD' :  { "pair" :  'EUR_AUD', "units": 1000, "pip": 0.0001},
    #'CAD_JPY' :  { "pair" :  'CAD_JPY', "units": 1000, "pip": 0.01},
    #'XAU_USD' :  { "pair" :  'XAU_USD', "units": 1,    "pip": 0.1}
    
}

with open('settings1.json', 'w') as outfile:
    json.dump(data, outfile)
###

class Settings():
    def __init__(self, pair, units,pip):
        self.pair = pair
        self.units = units
        self.pip = pip

    def __repr__(self):
        return str(vars(self))
    
    #return details of json file above as settings class
    @classmethod
    def from_file_ob(cls, ob):
        return Settings(ob['pair'],ob['units'], ob['pip'])
    
    @classmethod
    def load_settings(cls):
        data = json.loads(open('settings1.json', 'r').read())
        return { k:cls.from_file_ob(v) for k,v in data.items() }
    
    #only get pairs from settings file
    @classmethod
    def get_pairs(cls):
        return list(cls.load_settings().keys())

if __name__ == "__main__":
    #[print(k,v) for k,v in Settings.load_settings().items()]
    #print(Settings.get_pairs())
    print(Settings.load_settings()['GBP_JPY'])
# Out:
# {'pair': 'GBP_JPY', 'units': 1000, 'pip': 0.01}

# %%
# if there is no last candle, we set the timing to 10 minutes before, so we do not miss this current first candle 
# when it ends
class Timing():
    def __init__(self,last_candle):
        self.last_candle = last_candle
        if self.last_candle is None:
            self.last_candle = time_utc()-dt.timedelta(minutes=5)
        #set to true when have new candle
        self.ready=False
    
    #when init, it will run repr, which prints out a dict of all self.items
    def __repr__(self):
        return str(vars(self))

# %%
BUY =1
SELL =-1
NONE = 0

class Technicals():
    def __init__(self,settings,api,pair,granularity,log = None):
        self.settings=settings
        self.settings_loaded= Settings.load_settings()
        self.api = api
        self.log = log
        self.pair = pair
        self.granularity = granularity
        
    def log_message(self,msg):
        if self.log is not None:
            self.log.logger.debug(msg)
    
    def fetch_candles(self,row_count,candle_time):
        status_code, df = self.api.fetch_candles(self.pair, count=row_count, granularity=self.granularity)
        if df is None:
            print('df error')
            self.log_message(f"Error fetching candles for pair:{self.pair} {candle_time}, df None")
            return None
        #when u fetch candles, the last candle must be same as the candle stored in Timing above
        elif df.iloc[-1].time>candle_time:
            print (status_code, 'iloc_error >')
            temp_df = pd.read_pickle('iloc_error.pkl')
            temp_df = temp_df.append(df)
            temp_df.to_pickle('iloc_error.pkl')
            self.log_message(f"Error fetching candles for pair:{self.pair} {candle_time} vs {df.iloc[-1].time}")
            return df
        
        elif df.iloc[-1].time<candle_time:
            print (status_code, 'iloc_error <')
            self.log_message('decision =0')
            self.log_message(f"Error fetching candles for pair:{self.pair} {candle_time} vs {df.iloc[-1].time}")
            return None
        
        else:
            return df
            
    #return 1 if buy and -1 if sell
    def process_candles(self,df):
    
         df = df[['time','mid_c','mid_o']].copy()
            
         df['PAIR']= self.pair

         df['prev_close_m2']= df.mid_c.shift(2)

         df['prev_close_m1']= df.mid_c.shift(1)

         df['prev_open_m2']= df.mid_o.shift(2)

         df['prev_open_m1']= df.mid_o.shift(1)

         df['prev_close_m30']= df.mid_c.shift(30)
        
         last = df.iloc[-1]

         decision = NONE
         sup_com_df = pd.read_pickle(f'com/{self.pair}_com_sup.pkl')
         res_com_df = pd.read_pickle(f'com/{self.pair}_com_resist.pkl')

         #
         sup_df = pd.read_pickle(f'{self.pair}_pivots_support.pkl')
         res_df = pd.read_pickle(f'{self.pair}_pivots_resist.pkl')

         for x in sup_df.index:
            upper_limit = sup_df['sup_level'][x] + self.settings_loaded[self.pair].pip*10
            lower_limit = sup_df['sup_level'][x] - self.settings_loaded[self.pair].pip*10
            if sup_df['sup_level'][x] not in sup_com_df.values:
                if last['prev_close_m2']<last['prev_open_m2'] and last['prev_close_m2']<upper_limit and last['prev_close_m2']>lower_limit:
                    if last['prev_close_m1']>last['prev_open_m1'] and last['mid_c']>last['mid_o'] and last['mid_c']>upper_limit:
                        if last['prev_close_m30']>last['mid_c']:
                            decision = BUY
                            self.add_to_com_sup(sup_df['dates'][x],sup_df['sup_level'][x])
                            self.log_message(f"decision details\n{sup_df['dates'][x]}: {sup_df['sup_level'][x]}")
                    
                            log_cols = ['time','PAIR','prev_close_m30','prev_open_m2','prev_close_m2','prev_open_m1','prev_close_m1','mid_o','mid_c']
                            temp_df = df[log_cols].tail(1)
                            temp_df["sure_level"]= sup_df['sup_level'][x]
                            temp_df['upper_limit']=upper_limit
                            temp_df['lower_limit']=lower_limit
                            temp_df['decision']=decision
                            temp_df1= pd.read_pickle('respect_sure_buy_log.pkl')
                            temp_df1 = temp_df1.append(temp_df)
                            temp_df1.to_pickle('respect_sure_buy_log.pkl')

         for x in res_df.index:
            upper_limit = res_df['res_level'][x] + self.settings_loaded[self.pair].pip*10
            lower_limit = res_df['res_level'][x] - self.settings_loaded[self.pair].pip*10
            if res_df['res_level'][x] not in res_com_df.values:
                if last['prev_close_m2']>last['prev_open_m2'] and last['prev_close_m2']<upper_limit and last['prev_close_m2']>lower_limit:
                    if last['prev_close_m1']<last['prev_open_m1'] and last['mid_c']<last['mid_o'] and last['mid_c']<lower_limit:
                        if last['prev_close_m30']<last['mid_c']:
                            decision = SELL
                            self.add_to_com_resist(res_df['dates'][x],res_df['res_level'][x])
                            self.log_message(f"decision details\n{res_df['dates'][x]}: {res_df['res_level'][x]}")

                            log_cols = ['time','PAIR','prev_close_m30','prev_open_m2','prev_close_m2','prev_open_m1','prev_close_m1','mid_o','mid_c']
                            temp_df = df[log_cols].tail(1).copy()
                            temp_df.reset_index(inplace=True,drop=True)
                            temp_df["sure_level"]= res_df['res_level'][x]
                            temp_df['upper_limit']=upper_limit
                            temp_df['lower_limit']=lower_limit
                            temp_df['decision']=decision
                            temp_df1= pd.read_pickle('respect_sure_buy_log.pkl')
                            temp_df1 = temp_df1.append(temp_df)
                            temp_df1.to_pickle('respect_sure_buy_log.pkl')
                    
         log_cols = ['time','PAIR','mid_o','mid_c','prev_close_m2','prev_close_m1','prev_open_m2','prev_open_m1']
         self.log_message(f"Trade_decision:{decision}")
         self.log_message(f"Processed_df\n{df[log_cols].tail(3)}")
         #
         return decision
    
    #get df and run process_candles
    def get_trade_decision(self, candle_time):
        self.log_message(f'get_trade_decision() pair:{self.pair}')
        
        df = self.fetch_candles(32,candle_time)
        
        if df is not None:
            return self.process_candles(df)
        
        return None
    
    def add_to_com_sup(self,date,sup_level):
        temp_df = pd.read_pickle(f'com/{self.pair}_com_sup.pkl')
        new_temp_df = pd.DataFrame({'date':[date],'sup_level':[sup_level],'date_bought':[dt.datetime.utcnow()]})
        temp_df = temp_df.append(new_temp_df)
        temp_df.to_pickle(f'com/{self.pair}_com_sup.pkl')  
        
    def add_to_com_resist(self,date,res_level):
        temp_df = pd.read_pickle(f'com/{self.pair}_com_resist.pkl')
        new_temp_df = pd.DataFrame({'date':[date],'res_level':[res_level],'date_bought':[dt.datetime.utcnow()]})
        temp_df = temp_df.append(new_temp_df)
        temp_df.to_pickle(f'com/{self.pair}_com_resist.pkl')

# %%
class TradeManager():
    def __init__(self,api,settings,log=None):
        self.api=api
        self.settings = settings
        self.settings_loaded= Settings.load_settings()
        self.log= log
        
    def log_message(self,msg):
        if self.log is not None:
            self.log.logger.debug(msg)
    
    def place_trades(self,trades_to_make):
        self.log_message(f'TradeManager:place_trades() {trades_to_make}')
        
        #original>
        #pairs = [x['pair'] for x in trades_to_make]
        
        # proposed change
        pairs = []
        open_trades, ok = self.api.open_trades()
        for x in trades_to_make:
          for y in open_trades:
             if x['pair']==y.instrument:
                if x['units']<0 and y.currentUnits>0:
                    pairs.append(y.instrument)
                elif x['units']>0 and y.currentUnits<0:
                    pairs.append(y.instrument)
        
        self.close_trades(pairs)
        self.create_trades(trades_to_make)
        
    #use oandaapi to place trade for each dict item in trades to make and return trade id
                
    def create_trades(self,trades_to_make):
        for t in trades_to_make:
            trade_id = self.api.place_trade(t['pair'],t['units'],take_profit=self.settings_loaded[t['pair']].pip*20, stop_loss=self.settings_loaded[t['pair']].pip*20)
            
            if trade_id is not None:
                self.log_message(f"TradeManager:Opened {trade_id} {t}")
            else:
                self.log_message(f"TradeManager:FAILED TO OPEN {t}")
                 
    def close_trades(self,pairs_to_close):
        open_trades, ok = self.api.open_trades()
        
        if ok==False:
            self.log_message('Error fetching open trades!')
            return
        #get the trade ids from the OandaTrade objects in open_trades, return its instruments and check if those are>
        #in pairs_to_close, which are the pairs we are looking to trade now
        ids_to_close =[x.trade_id for x in open_trades if x.instrument in pairs_to_close]
        
        self.log_message(f"TradeManager:close_trades() pairs_to_close:{pairs_to_close} ")
        self.log_message(f"TradeManager:close_trades() open_trades:{open_trades} ")
        self.log_message(f"TradeManager:close_trades() ids_to_close:{ids_to_close} ")
        
        # close trade and check status
        for t in ids_to_close:
            ok = self.api.close_trade(t)
            if ok == False:
                self.log_message(f"TradeManager:close_trades() {t} FAILED TO CLOSE ")
            else:
                self.log_message(f"TradeManager:close_trades() Closed")

# %%
GRANULARITY = 'M1'
SLEEP = 5.0

class TradingBot():
    
    def __init__(self):  
        #create a log everytime we start bot with printed settings
        self.log = LogWrapper("Bot")
        self.tech_log= LogWrapper("Technicals")
        self.trade_log= LogWrapper("Trade")
        self.trade_pairs = Settings.get_pairs()
        self.settings = Settings.load_settings()
        self.api = OandaAPI()
        self.trade_manager = TradeManager(self.api,self.settings,self.trade_log)
        #when init, self.timings is the dictionary of the timings of the timings of the pair (when started)
        self.timings = {p: Timing(self.api.last_complete_candle(p,GRANULARITY)) for p in self.trade_pairs}
        self.log_message(f"Bot started with\n{pprint.pformat(self.settings)}")
        self.log_message(f"Bot Timings\n{pprint.pformat(self.timings)}")
    
    # create this function, which runs the msg. during init, it will run the function above
    def log_message(self, msg):
        self.log.logger.debug(msg)
        
    # update timing of pair if current timing is more than previous timing. change status of pair to ready to trade
    def update_timings(self):
        for pair in self.trade_pairs:
            #fetch candles and check what is the timing and store it in current
            current = self.api.last_complete_candle(pair,GRANULARITY)
            self.timings[pair].ready = False
            #if current is more than the stored self.timings pair in the timings dict, update self.timings pair>
            #last timing
            if current> self.timings[pair].last_candle:
                self.timings[pair].ready = True  
                self.timings[pair].last_candle = current
                self.log_message(f'{pair}new candle {current}')
    
    def process_pairs(self):
        d = dt.datetime.utcnow().time()
        d1= dt.time(20,56)
        d2 = dt.time(21,0)

        if d>d1 and d<d2:
            trades, ok = self.api.open_trades()
            if ok == True:
                ok1 = [self.api.close_trade(t.trade_id) for t in trades]
                if ok1 == False:
                    self.log_message(f"TradeManager:close_trades() {t} FAILED TO CLOSE ")
                else:
                    self.log_message(f"TradeManager:close_trades() Closed at 5am")
                    
        trades_to_make = []
        
        for pair in self.trade_pairs:
            if self.timings[pair].ready == True:
                self.log_message(f'Ready to trade {pair}')
                techs = Technicals(self.settings[pair], self.api, pair, GRANULARITY, log=self.tech_log)
                decision = techs.get_trade_decision(self.timings[pair].last_candle)
                if decision == None:
                    print ('error decision 0')
                    decision = 0
                units = decision*self.settings[pair].units
                if units != 0:
                    trades_to_make.append({'pair':pair, 'units':units})
        
        if len(trades_to_make) >0:
            d = dt.datetime.utcnow().time()
            d1= dt.time(20,30)
            d2 = dt.time(22,30)
            if d<d1 or d> d2:
                print (trades_to_make)
                self.trade_manager.place_trades(trades_to_make)
    
    def run(self):
        while True:
            print ('update_timings()...', dt.datetime.now())
            self.update_timings()
            print ('process_pairs()...')
            self.process_pairs()
            time.sleep(SLEEP)

if __name__ == "__main__":
    b = TradingBot()
    b.run()
# Out:
# update_timings()... 2021-06-26 02:20:39.970278
# process_pairs()...
# update_timings()... 2021-06-26 02:20:46.408246
# process_pairs()...
# update_timings()... 2021-06-26 02:20:52.965408
# process_pairs()...
# update_timings()... 2021-06-26 02:20:59.410938
# process_pairs()...
# update_timings()... 2021-06-26 02:21:06.315561
# process_pairs()...
# update_timings()... 2021-06-26 02:21:14.073333
# process_pairs()...
# update_timings()... 2021-06-26 02:21:20.617009
# process_pairs()...
# update_timings()... 2021-06-26 02:21:27.063876
# process_pairs()...
# update_timings()... 2021-06-26 02:21:33.589473
# process_pairs()...
# update_timings()... 2021-06-26 02:21:40.078193
# process_pairs()...
# update_timings()... 2021-06-26 02:21:53.824870
# process_pairs()...
# update_timings()... 2021-06-26 02:22:00.439638
# process_pairs()...
# update_timings()... 2021-06-26 02:22:06.901931
# process_pairs()...
# update_timings()... 2021-06-26 02:22:14.682095
# process_pairs()...
# update_timings()... 2021-06-26 02:22:21.084897
# process_pairs()...
# update_timings()... 2021-06-26 02:22:27.496567
# process_pairs()...
# update_timings()... 2021-06-26 02:22:34.025221
# process_pairs()...
# update_timings()... 2021-06-26 02:22:40.475542
# process_pairs()...
# update_timings()... 2021-06-26 02:22:47.032200
# process_pairs()...
# update_timings()... 2021-06-26 02:22:53.550155
# process_pairs()...
# update_timings()... 2021-06-26 02:22:59.992732
# process_pairs()...
# update_timings()... 2021-06-26 02:23:06.834559
# process_pairs()...
# update_timings()... 2021-06-26 02:23:14.691643
# process_pairs()...
# update_timings()... 2021-06-26 03:05:08.909716
# process_pairs()...
# update_timings()... 2021-06-26 03:05:16.015614
# process_pairs()...
# update_timings()... 2021-06-26 03:05:22.472012
# process_pairs()...
# update_timings()... 2021-06-26 03:05:28.894270
# process_pairs()...
# update_timings()... 2021-06-26 03:05:35.345523
# process_pairs()...
# update_timings()... 2021-06-26 03:05:41.756195
# process_pairs()...
# update_timings()... 2021-06-26 03:05:48.165605
# process_pairs()...
# update_timings()... 2021-06-26 03:05:54.708779
# process_pairs()...
# update_timings()... 2021-06-26 03:06:01.150752
# process_pairs()...
# update_timings()... 2021-06-26 03:06:08.235745
# process_pairs()...
# update_timings()... 2021-06-26 03:06:15.724990
# process_pairs()...
# update_timings()... 2021-06-26 03:06:22.177220
# process_pairs()...
# update_timings()... 2021-06-26 03:06:28.669570
# process_pairs()...
# update_timings()... 2021-06-26 03:06:35.148471
# process_pairs()...
# update_timings()... 2021-06-26 03:06:41.557796
# process_pairs()...
# update_timings()... 2021-06-26 03:06:47.986437
# process_pairs()...
# update_timings()... 2021-06-26 03:06:54.524105
# process_pairs()...
# update_timings()... 2021-06-26 03:07:00.945381
# process_pairs()...
# update_timings()... 2021-06-26 03:07:08.479948
# process_pairs()...
# update_timings()... 2021-06-26 03:07:15.556620
# process_pairs()...
# update_timings()... 2021-06-26 03:07:22.037529
# process_pairs()...
# update_timings()... 2021-06-26 03:07:28.422344
# process_pairs()...
# update_timings()... 2021-06-26 03:07:34.958950
# process_pairs()...
# update_timings()... 2021-06-26 03:07:41.515617
# process_pairs()...
# update_timings()... 2021-06-26 03:07:47.915588
# process_pairs()...
# update_timings()... 2021-06-26 03:07:54.283961
# process_pairs()...
# update_timings()... 2021-06-26 03:08:00.715609
# process_pairs()...
# update_timings()... 2021-06-26 03:08:07.587341
# process_pairs()...
# update_timings()... 2021-06-26 03:08:15.287656
# process_pairs()...
# update_timings()... 2021-06-26 03:08:21.735589
# process_pairs()...
# update_timings()... 2021-06-26 03:08:28.416220
# process_pairs()...
# update_timings()... 2021-06-26 03:08:34.840978
# process_pairs()...
# update_timings()... 2021-06-26 03:08:41.217281
# process_pairs()...
# update_timings()... 2021-06-26 03:08:47.856268
# process_pairs()...
# update_timings()... 2021-06-26 03:08:54.367642
# process_pairs()...
# update_timings()... 2021-06-26 03:09:00.857032
# process_pairs()...
# update_timings()... 2021-06-26 03:09:07.297969
# process_pairs()...
# update_timings()... 2021-06-26 03:09:15.355647
# process_pairs()...
# update_timings()... 2021-06-26 03:09:21.849199
# process_pairs()...
# update_timings()... 2021-06-26 03:09:28.376258
# process_pairs()...
# update_timings()... 2021-06-26 03:09:34.867444
# process_pairs()...
# update_timings()... 2021-06-26 03:09:41.541893
# process_pairs()...
# update_timings()... 2021-06-26 03:09:48.458447
# process_pairs()...
# update_timings()... 2021-06-26 03:09:54.943661
# process_pairs()...
# update_timings()... 2021-06-26 03:10:01.506912
# process_pairs()...
# update_timings()... 2021-06-26 03:10:08.274474
# process_pairs()...
# update_timings()... 2021-06-26 03:10:16.234830
# process_pairs()...
# update_timings()... 2021-06-26 03:10:22.699291
# process_pairs()...
# update_timings()... 2021-06-26 03:10:29.165562
# process_pairs()...
# update_timings()... 2021-06-26 03:10:35.587497
# process_pairs()...
# update_timings()... 2021-06-26 03:10:42.143989
# process_pairs()...
# update_timings()... 2021-06-26 03:10:48.683252
# process_pairs()...
# update_timings()... 2021-06-26 03:10:55.251283
# process_pairs()...
# update_timings()... 2021-06-26 03:11:01.780235
# process_pairs()...
# update_timings()... 2021-06-26 03:11:08.694626
# process_pairs()...
# update_timings()... 2021-06-26 03:11:16.388896
# process_pairs()...
# update_timings()... 2021-06-26 03:11:23.032611
# process_pairs()...
# update_timings()... 2021-06-26 03:11:29.447607
# process_pairs()...
# update_timings()... 2021-06-26 03:11:36.161129
# process_pairs()...
# update_timings()... 2021-06-26 03:11:42.666884
# process_pairs()...
# update_timings()... 2021-06-26 03:11:49.315563
# process_pairs()...
# update_timings()... 2021-06-26 03:11:55.752014
# process_pairs()...
# update_timings()... 2021-06-26 03:12:02.265594
# process_pairs()...
# update_timings()... 2021-06-26 03:12:09.241758
# process_pairs()...
# update_timings()... 2021-06-26 03:12:16.887555
# process_pairs()...
# update_timings()... 2021-06-26 03:12:23.532067
# process_pairs()...
# update_timings()... 2021-06-26 03:12:30.055774
# process_pairs()...
# update_timings()... 2021-06-26 03:12:36.515570
# process_pairs()...
# update_timings()... 2021-06-26 03:12:42.934943
# process_pairs()...
# update_timings()... 2021-06-26 03:12:49.376661
# process_pairs()...
# update_timings()... 2021-06-26 03:12:55.820653
# process_pairs()...
# update_timings()... 2021-06-26 03:13:02.483539
# process_pairs()...
# update_timings()... 2021-06-26 03:13:09.675019
# process_pairs()...
# update_timings()... 2021-06-26 03:13:17.110358
# process_pairs()...
# update_timings()... 2021-06-26 03:13:23.732131
# process_pairs()...
# update_timings()... 2021-06-26 03:13:30.190816
# process_pairs()...
# update_timings()... 2021-06-26 03:13:36.737604
# process_pairs()...
# update_timings()... 2021-06-26 03:13:43.188201
# process_pairs()...
# update_timings()... 2021-06-26 03:13:49.640064
# process_pairs()...
# update_timings()... 2021-06-26 03:13:56.139461
# process_pairs()...
# update_timings()... 2021-06-26 03:14:02.626707
# process_pairs()...
# update_timings()... 2021-06-26 03:14:10.139367
# process_pairs()...
# update_timings()... 2021-06-26 03:14:17.265566
# process_pairs()...
# update_timings()... 2021-06-26 03:14:23.777297
# process_pairs()...
# update_timings()... 2021-06-26 03:14:30.397040
# process_pairs()...
# update_timings()... 2021-06-26 03:14:37.050252
# process_pairs()...
# update_timings()... 2021-06-26 03:14:43.582065
# process_pairs()...
# update_timings()... 2021-06-26 03:14:50.325486
# process_pairs()...
# update_timings()... 2021-06-26 03:14:56.818172
# process_pairs()...
# update_timings()... 2021-06-26 03:15:03.353412
# process_pairs()...
# update_timings()... 2021-06-26 03:15:10.421783
# process_pairs()...
# update_timings()... 2021-06-26 03:15:17.825966
# process_pairs()...
# update_timings()... 2021-06-26 03:15:24.311190
# process_pairs()...
# update_timings()... 2021-06-26 03:15:30.751645
# process_pairs()...
# update_timings()... 2021-06-26 03:15:37.264517
# process_pairs()...
# update_timings()... 2021-06-26 03:15:43.850249
# process_pairs()...
# update_timings()... 2021-06-26 03:15:50.343597
# process_pairs()...
# update_timings()... 2021-06-26 03:15:56.763494
# process_pairs()...
# update_timings()... 2021-06-26 03:16:03.325397
# process_pairs()...
# update_timings()... 2021-06-26 03:16:11.488442
# process_pairs()...
# update_timings()... 2021-06-26 03:16:18.459033
# process_pairs()...
# update_timings()... 2021-06-26 03:16:24.882144
# process_pairs()...
# update_timings()... 2021-06-26 03:16:31.338390
# process_pairs()...
# update_timings()... 2021-06-26 03:16:37.859510
# process_pairs()...
# update_timings()... 2021-06-26 03:16:44.332109
# process_pairs()...
# update_timings()... 2021-06-26 03:16:50.732109
# process_pairs()...
# update_timings()... 2021-06-26 03:16:57.151868
# process_pairs()...
# update_timings()... 2021-06-26 03:17:03.560342
# process_pairs()...
# update_timings()... 2021-06-26 03:17:11.298597
# process_pairs()...
# update_timings()... 2021-06-26 03:17:18.089033
# process_pairs()...
# update_timings()... 2021-06-26 03:17:24.687382
# process_pairs()...
# update_timings()... 2021-06-26 03:17:31.296494
# process_pairs()...
# update_timings()... 2021-06-26 03:17:37.787396
# process_pairs()...
# update_timings()... 2021-06-26 03:17:44.202604
# process_pairs()...
# update_timings()... 2021-06-26 03:17:50.763977
# process_pairs()...
# update_timings()... 2021-06-26 03:17:57.252011
# process_pairs()...
# update_timings()... 2021-06-26 03:18:03.793074
# process_pairs()...
# update_timings()... 2021-06-26 03:18:10.547947
# process_pairs()...
# update_timings()... 2021-06-26 03:18:18.584203
# process_pairs()...
# update_timings()... 2021-06-26 03:18:25.300332
# process_pairs()...
# update_timings()... 2021-06-26 03:18:31.832110
# process_pairs()...
# update_timings()... 2021-06-26 03:18:38.342159
# process_pairs()...
# update_timings()... 2021-06-26 03:18:45.062685
# process_pairs()...
# update_timings()... 2021-06-26 03:18:51.821133
# process_pairs()...
# update_timings()... 2021-06-26 03:18:58.320991
# process_pairs()...
# update_timings()... 2021-06-26 03:19:05.241919
# process_pairs()...
# update_timings()... 2021-06-26 03:19:13.165893
# process_pairs()...
# update_timings()... 2021-06-26 03:19:19.753784
# process_pairs()...
# update_timings()... 2021-06-26 03:19:26.164802
# process_pairs()...
# update_timings()... 2021-06-26 03:19:32.691048
# process_pairs()...
# update_timings()... 2021-06-26 03:19:39.104344
# process_pairs()...
# update_timings()... 2021-06-26 03:19:45.696535
# process_pairs()...
# update_timings()... 2021-06-26 03:19:52.722776
# process_pairs()...
# update_timings()... 2021-06-26 03:19:59.232059
# process_pairs()...
# update_timings()... 2021-06-26 03:20:05.828837
# process_pairs()...
# update_timings()... 2021-06-26 03:20:13.511351
# process_pairs()...
# update_timings()... 2021-06-26 03:20:19.961741
# process_pairs()...
# update_timings()... 2021-06-26 03:20:26.441365
# process_pairs()...
# update_timings()... 2021-06-26 03:20:32.966185
# process_pairs()...
# update_timings()... 2021-06-26 03:25:54.132640
# process_pairs()...
# update_timings()... 2021-06-26 03:26:00.658300
# process_pairs()...
# update_timings()... 2021-06-26 03:26:07.758228
# process_pairs()...
# update_timings()... 2021-06-26 03:26:15.246654
# process_pairs()...
# update_timings()... 2021-06-26 03:26:21.854193
# process_pairs()...
# update_timings()... 2021-06-26 03:26:28.298380
# process_pairs()...
# update_timings()... 2021-06-26 03:26:34.758269
# process_pairs()...
# update_timings()... 2021-06-26 03:26:41.208230
# process_pairs()...
# update_timings()... 2021-06-26 03:26:47.627991
# process_pairs()...
# update_timings()... 2021-06-26 03:26:54.118285
# process_pairs()...
# update_timings()... 2021-06-26 03:27:00.582064
# process_pairs()...
# update_timings()... 2021-06-26 03:27:07.646239
# process_pairs()...
# update_timings()... 2021-06-26 03:27:14.858236
# process_pairs()...
# update_timings()... 2021-06-26 03:27:21.465967
# process_pairs()...
# update_timings()... 2021-06-26 03:27:27.932421
# process_pairs()...
# update_timings()... 2021-06-26 03:27:34.408326
# process_pairs()...
# update_timings()... 2021-06-26 03:27:41.293771
# process_pairs()...
# update_timings()... 2021-06-26 03:27:47.882060
# process_pairs()...
# update_timings()... 2021-06-26 03:27:54.344544
# process_pairs()...
# update_timings()... 2021-06-26 03:28:00.759292
# process_pairs()...
# update_timings()... 2021-06-26 03:28:08.709903
# process_pairs()...
# update_timings()... 2021-06-26 03:28:15.159311
# process_pairs()...
# update_timings()... 2021-06-26 03:28:21.597360
# process_pairs()...
# update_timings()... 2021-06-26 03:28:28.032072
# process_pairs()...
# update_timings()... 2021-06-26 03:28:34.482494
# process_pairs()...
# update_timings()... 2021-06-26 03:28:41.032064
# process_pairs()...
# update_timings()... 2021-06-26 03:28:47.446246
# process_pairs()...
# update_timings()... 2021-06-26 03:28:53.876226
# process_pairs()...
# update_timings()... 2021-06-26 03:29:00.507068
# process_pairs()...
# update_timings()... 2021-06-26 03:29:09.018506
# process_pairs()...
# update_timings()... 2021-06-26 03:29:15.432034
# process_pairs()...
# update_timings()... 2021-06-26 03:29:21.990141
# process_pairs()...
# update_timings()... 2021-06-26 03:29:28.509596
# process_pairs()...
# update_timings()... 2021-06-26 03:29:34.996477
# process_pairs()...
# update_timings()... 2021-06-26 03:29:41.454054
# process_pairs()...
# update_timings()... 2021-06-26 03:29:48.104703
# process_pairs()...
# update_timings()... 2021-06-26 03:29:54.669756
# process_pairs()...
# update_timings()... 2021-06-26 03:30:01.182110
# process_pairs()...
# update_timings()... 2021-06-26 03:30:09.335278
# process_pairs()...
# update_timings()... 2021-06-26 03:30:15.752217
# process_pairs()...
# update_timings()... 2021-06-26 03:30:22.303549
# process_pairs()...
# update_timings()... 2021-06-26 03:30:28.965891
# process_pairs()...
# update_timings()... 2021-06-26 03:30:35.432079
# process_pairs()...
# update_timings()... 2021-06-26 03:30:41.936397
# process_pairs()...
# update_timings()... 2021-06-26 03:30:48.525614
# process_pairs()...
# update_timings()... 2021-06-26 03:30:54.976292
# process_pairs()...
# update_timings()... 2021-06-26 03:31:01.563176
# process_pairs()...
# update_timings()... 2021-06-26 03:31:08.282252
# process_pairs()...
# update_timings()... 2021-06-26 03:31:16.098559
# process_pairs()...
# update_timings()... 2021-06-26 03:31:22.524878
# process_pairs()...
# update_timings()... 2021-06-26 03:31:28.959737
# process_pairs()...
# update_timings()... 2021-06-26 03:31:35.481180
# process_pairs()...
# update_timings()... 2021-06-26 03:31:42.080402
# process_pairs()...
# update_timings()... 2021-06-26 03:31:48.731688
# process_pairs()...
# update_timings()... 2021-06-26 03:31:55.182693
# process_pairs()...
# update_timings()... 2021-06-26 03:32:01.638877
# process_pairs()...
# update_timings()... 2021-06-26 03:32:08.607252
# process_pairs()...
# update_timings()... 2021-06-26 03:32:16.533521
# process_pairs()...
# update_timings()... 2021-06-26 03:32:22.948642
# process_pairs()...
# update_timings()... 2021-06-26 03:32:29.475539
# process_pairs()...
# update_timings()... 2021-06-26 03:32:35.980694
# process_pairs()...
# update_timings()... 2021-06-26 03:32:42.494919
# process_pairs()...
# update_timings()... 2021-06-26 03:32:49.038092
# process_pairs()...
# update_timings()... 2021-06-26 03:32:55.555949
# process_pairs()...
# update_timings()... 2021-06-26 03:33:02.247640
# process_pairs()...
# update_timings()... 2021-06-26 03:33:09.238204
# process_pairs()...
# update_timings()... 2021-06-26 03:33:16.732868
# process_pairs()...
# update_timings()... 2021-06-26 03:33:23.213445
# process_pairs()...
# update_timings()... 2021-06-26 03:33:29.793422
# process_pairs()...
# update_timings()... 2021-06-26 03:33:36.251854
# process_pairs()...
# update_timings()... 2021-06-26 03:33:42.681847
# process_pairs()...
# update_timings()... 2021-06-26 03:33:49.301276
# process_pairs()...
# update_timings()... 2021-06-26 03:33:55.820641
# process_pairs()...
# update_timings()... 2021-06-26 03:34:02.356834
# process_pairs()...
# update_timings()... 2021-06-26 03:34:09.719069
# process_pairs()...
# update_timings()... 2021-06-26 03:34:17.072961
# process_pairs()...
# update_timings()... 2021-06-26 03:34:23.657525
# process_pairs()...
# update_timings()... 2021-06-26 03:34:30.110143
# process_pairs()...
# update_timings()... 2021-06-26 03:34:36.567676
# process_pairs()...
# update_timings()... 2021-06-26 03:34:43.102626
# process_pairs()...
# update_timings()... 2021-06-26 03:34:49.671896
# process_pairs()...
# update_timings()... 2021-06-26 03:34:56.140559
# process_pairs()...
# update_timings()... 2021-06-26 03:35:02.630677
# process_pairs()...
# update_timings()... 2021-06-26 03:35:09.763940
# process_pairs()...
# update_timings()... 2021-06-26 03:35:17.022488
# process_pairs()...
# update_timings()... 2021-06-26 03:35:23.459603
# process_pairs()...
# update_timings()... 2021-06-26 03:35:29.911008
# process_pairs()...
# update_timings()... 2021-06-26 03:35:36.389164
# process_pairs()...
# update_timings()... 2021-06-26 03:35:43.021562
# process_pairs()...
# update_timings()... 2021-06-26 03:35:49.488522
# process_pairs()...
# update_timings()... 2021-06-26 03:35:55.917536
# process_pairs()...
# update_timings()... 2021-06-26 03:36:02.446280
# process_pairs()...
# update_timings()... 2021-06-26 03:36:09.861901
# process_pairs()...
# process_pairs()...
# update_timings()... 2021-06-26 03:41:33.517089
# process_pairs()...
# update_timings()... 2021-06-26 03:41:40.144848
# process_pairs()...
# update_timings()... 2021-06-26 03:41:46.665050
# process_pairs()...
# update_timings()... 2021-06-26 03:41:53.184548
# process_pairs()...
# update_timings()... 2021-06-26 03:41:59.832729
# process_pairs()...
# update_timings()... 2021-06-26 03:42:06.317254
# process_pairs()...
# update_timings()... 2021-06-26 03:42:14.391009
# process_pairs()...
# update_timings()... 2021-06-26 03:42:21.041610
# process_pairs()...
# update_timings()... 2021-06-26 03:42:27.511231
# process_pairs()...
# update_timings()... 2021-06-26 03:42:34.124078
# process_pairs()...
# update_timings()... 2021-06-26 03:42:40.689457
# process_pairs()...
# update_timings()... 2021-06-26 03:42:47.218567
# process_pairs()...
# update_timings()... 2021-06-26 03:42:53.771445
# process_pairs()...
# update_timings()... 2021-06-26 03:43:01.183629
# process_pairs()...
# update_timings()... 2021-06-26 03:43:08.368927
# process_pairs()...
# update_timings()... 2021-06-26 03:43:16.063795
# process_pairs()...
# update_timings()... 2021-06-26 03:43:22.554054
# process_pairs()...
# update_timings()... 2021-06-26 03:43:29.020618
# process_pairs()...
# update_timings()... 2021-06-26 03:43:35.591725
# process_pairs()...
# update_timings()... 2021-06-26 03:43:42.129960
# process_pairs()...
# update_timings()... 2021-06-26 03:43:48.698316
# process_pairs()...
# update_timings()... 2021-06-26 03:43:55.164422
# process_pairs()...
# update_timings()... 2021-06-26 03:44:01.893125
# process_pairs()...
# update_timings()... 2021-06-26 03:44:09.175703
# process_pairs()...
# update_timings()... 2021-06-26 03:44:16.902114
# process_pairs()...
# update_timings()... 2021-06-26 03:44:23.492191
# process_pairs()...
# update_timings()... 2021-06-26 03:44:29.949836
# process_pairs()...
# update_timings()... 2021-06-26 03:44:36.500990
# process_pairs()...
# update_timings()... 2021-06-26 03:44:42.962437
# process_pairs()...
# update_timings()... 2021-06-26 03:44:49.718411
# process_pairs()...
# update_timings()... 2021-06-26 03:44:56.377726
# process_pairs()...
# update_timings()... 2021-06-26 03:45:02.990959
# process_pairs()...
# update_timings()... 2021-06-26 03:45:10.960900
# process_pairs()...
# update_timings()... 2021-06-26 03:45:17.971671
# process_pairs()...
# update_timings()... 2021-06-26 03:45:24.496643
# process_pairs()...
# update_timings()... 2021-06-26 03:45:31.089365
# process_pairs()...
# update_timings()... 2021-06-26 03:45:37.566711
# process_pairs()...
# update_timings()... 2021-06-26 03:45:44.181350
# process_pairs()...
# update_timings()... 2021-06-26 03:45:50.648982
# process_pairs()...
# update_timings()... 2021-06-26 03:45:57.197926
# process_pairs()...
# update_timings()... 2021-06-26 03:46:03.749052
# process_pairs()...
# update_timings()... 2021-06-26 03:46:11.745678
# process_pairs()...
# update_timings()... 2021-06-26 03:46:18.710066
# process_pairs()...
# update_timings()... 2021-06-26 03:46:25.155305
# process_pairs()...
# update_timings()... 2021-06-26 03:46:31.876692
# process_pairs()...
# update_timings()... 2021-06-26 03:46:38.353993
# process_pairs()...
# update_timings()... 2021-06-26 03:46:45.155092
# process_pairs()...
# update_timings()... 2021-06-26 03:46:51.681751
# process_pairs()...
# update_timings()... 2021-06-26 03:46:58.396101
# process_pairs()...
# update_timings()... 2021-06-26 03:47:04.868387
# process_pairs()...
# update_timings()... 2021-06-26 03:47:12.184665
# process_pairs()...
# update_timings()... 2021-06-26 03:47:19.310564
# process_pairs()...
# update_timings()... 2021-06-26 03:47:25.820108
# process_pairs()...
# update_timings()... 2021-06-26 03:47:32.416342
# process_pairs()...
# update_timings()... 2021-06-26 03:47:38.804995
# process_pairs()...
# update_timings()... 2021-06-26 03:47:45.419656
# process_pairs()...
# update_timings()... 2021-06-26 03:47:52.065508
# process_pairs()...
# update_timings()... 2021-06-26 03:47:58.950999
# process_pairs()...
# update_timings()... 2021-06-26 03:48:05.467672
# process_pairs()...
# update_timings()... 2021-06-26 03:48:13.604196
# process_pairs()...
# update_timings()... 2021-06-26 03:48:20.285929
# process_pairs()...
# update_timings()... 2021-06-26 03:48:26.789937
# process_pairs()...
# update_timings()... 2021-06-26 03:48:33.339150
# process_pairs()...
# update_timings()... 2021-06-26 03:48:39.897344
# process_pairs()...
# update_timings()... 2021-06-26 03:48:46.458494
# process_pairs()...
# update_timings()... 2021-06-26 03:48:53.008879
# process_pairs()...
# update_timings()... 2021-06-26 03:48:59.529365
# process_pairs()...
# update_timings()... 2021-06-26 03:49:06.702452
# process_pairs()...
# update_timings()... 2021-06-26 03:49:14.830610
# process_pairs()...
# update_timings()... 2021-06-26 03:49:21.365946
# process_pairs()...
# update_timings()... 2021-06-26 03:49:27.913815
# process_pairs()...
# update_timings()... 2021-06-26 03:49:34.575714
# process_pairs()...
# update_timings()... 2021-06-26 03:49:41.091521
# process_pairs()...
# update_timings()... 2021-06-26 03:49:47.790144
# process_pairs()...
# update_timings()... 2021-06-26 03:49:54.427800
# process_pairs()...
# update_timings()... 2021-06-26 03:50:00.955489
# process_pairs()...
# update_timings()... 2021-06-26 03:50:08.622797
# process_pairs()...
# update_timings()... 2021-06-26 03:50:16.217317
# process_pairs()...
# update_timings()... 2021-06-26 03:50:22.773723
# process_pairs()...
# update_timings()... 2021-06-26 03:50:29.501386
# process_pairs()...
# update_timings()... 2021-06-26 03:50:36.069920
# process_pairs()...
# update_timings()... 2021-06-26 03:50:42.877813
# process_pairs()...
# update_timings()... 2021-06-26 03:50:49.326319
# process_pairs()...
# update_timings()... 2021-06-26 03:50:55.921772
# process_pairs()...
# update_timings()... 2021-06-26 03:51:02.549104
# process_pairs()...
# update_timings()... 2021-06-26 03:51:09.835716
# process_pairs()...
# update_timings()... 2021-06-26 03:51:17.358283
# process_pairs()...
# update_timings()... 2021-06-26 03:51:23.848843
# process_pairs()...
# update_timings()... 2021-06-26 03:51:30.387059
# process_pairs()...
# update_timings()... 2021-06-26 03:51:37.043396
# process_pairs()...
# update_timings()... 2021-06-26 03:51:43.511650
# process_pairs()...
# update_timings()... 2021-06-26 03:51:49.999715
# process_pairs()...
# update_timings()... 2021-06-26 03:51:56.559604
# process_pairs()...
# update_timings()... 2021-06-26 03:52:03.289800
# process_pairs()...
# update_timings()... 2021-06-26 03:52:11.403174
# process_pairs()...
# update_timings()... 2021-06-26 03:52:18.350323
# process_pairs()...
# update_timings()... 2021-06-26 03:52:24.965322
# process_pairs()...
# update_timings()... 2021-06-26 03:52:31.436636
# process_pairs()...
# update_timings()... 2021-06-26 03:52:37.991318
# process_pairs()...
# update_timings()... 2021-06-26 03:52:44.462031
# process_pairs()...
# update_timings()... 2021-06-26 03:52:51.184162
# process_pairs()...
# update_timings()... 2021-06-26 03:52:57.730545
# process_pairs()...
# update_timings()... 2021-06-26 03:53:04.178132
# process_pairs()...
# update_timings()... 2021-06-26 03:53:12.204722
# process_pairs()...
# update_timings()... 2021-06-26 03:53:18.853161
# process_pairs()...
# update_timings()... 2021-06-26 03:53:25.378207
# process_pairs()...
# update_timings()... 2021-06-26 03:53:31.768544
# process_pairs()...
# update_timings()... 2021-06-26 03:53:38.482104
# process_pairs()...
# update_timings()... 2021-06-26 03:53:45.110049
# process_pairs()...
# update_timings()... 2021-06-26 03:53:51.527372
# process_pairs()...
# update_timings()... 2021-06-26 03:53:57.981147
# process_pairs()...
# update_timings()... 2021-06-26 03:54:04.515398
# process_pairs()...
# update_timings()... 2021-06-26 03:54:12.816450
# process_pairs()...
# update_timings()... 2021-06-26 03:54:19.272058
# process_pairs()...
# update_timings()... 2021-06-26 03:54:25.871649
# process_pairs()...
# update_timings()... 2021-06-26 03:54:32.636548
# process_pairs()...
# update_timings()... 2021-06-26 03:54:39.213117
# process_pairs()...
# update_timings()... 2021-06-26 03:54:45.977432
# process_pairs()...
# update_timings()... 2021-06-26 03:54:52.578711
# process_pairs()...
# update_timings()... 2021-06-26 03:54:59.087990
# process_pairs()...
# update_timings()... 2021-06-26 03:55:06.049048
# process_pairs()...
# update_timings()... 2021-06-26 03:55:13.780079
# process_pairs()...
# update_timings()... 2021-06-26 03:55:20.462280
# process_pairs()...
# update_timings()... 2021-06-26 03:55:27.091262
# process_pairs()...
# update_timings()... 2021-06-26 03:55:33.862400
# process_pairs()...
# update_timings()... 2021-06-26 03:55:40.436632
# process_pairs()...
# update_timings()... 2021-06-26 03:55:46.936129
# process_pairs()...
# update_timings()... 2021-06-26 03:55:53.538396
# process_pairs()...
# update_timings()... 2021-06-26 03:56:00.408396
# process_pairs()...
# update_timings()... 2021-06-26 03:56:08.128485
# process_pairs()...
# update_timings()... 2021-06-26 03:56:15.313319
# process_pairs()...
# update_timings()... 2021-06-26 03:56:21.891585
# process_pairs()...
# update_timings()... 2021-06-26 03:56:28.733265
# process_pairs()...
# update_timings()... 2021-06-26 03:56:35.428619
# process_pairs()...
# update_timings()... 2021-06-26 03:56:42.089048
# process_pairs()...
# update_timings()... 2021-06-26 03:56:48.636382
# process_pairs()...
# update_timings()... 2021-06-26 03:56:55.231012
# process_pairs()...
# update_timings()... 2021-06-26 03:57:01.904860
# process_pairs()...
# update_timings()... 2021-06-26 03:57:09.457194
# process_pairs()...
# update_timings()... 2021-06-26 03:57:16.736379
# process_pairs()...
# update_timings()... 2021-06-26 03:57:23.324158
# process_pairs()...
# update_timings()... 2021-06-26 03:57:29.835700
# process_pairs()...
# update_timings()... 2021-06-26 03:57:36.462211
# process_pairs()...
# update_timings()... 2021-06-26 03:57:42.966223
# process_pairs()...
# update_timings()... 2021-06-26 03:57:49.596041
# process_pairs()...
# update_timings()... 2021-06-26 03:57:56.179627
# process_pairs()...
# update_timings()... 2021-06-26 03:58:02.773163
# process_pairs()...
# update_timings()... 2021-06-26 03:58:10.891745
# process_pairs()...
# update_timings()... 2021-06-26 03:58:17.778985
# process_pairs()...
# update_timings()... 2021-06-26 03:58:24.499024
# process_pairs()...
# update_timings()... 2021-06-26 03:58:30.997432
# process_pairs()...
# update_timings()... 2021-06-26 03:58:37.558585
# process_pairs()...
# update_timings()... 2021-06-26 03:58:44.180443
# process_pairs()...
# update_timings()... 2021-06-26 03:58:51.105496
# process_pairs()...
# update_timings()... 2021-06-26 03:58:57.942546
# process_pairs()...
# update_timings()... 2021-06-26 03:59:04.525554
# process_pairs()...
# update_timings()... 2021-06-26 03:59:12.635147
# process_pairs()...
# update_timings()... 2021-06-26 03:59:19.374087
# process_pairs()...
# update_timings()... 2021-06-26 03:59:25.920490
# process_pairs()...
# update_timings()... 2021-06-26 03:59:32.505898
# process_pairs()...
# update_timings()... 2021-06-26 03:59:39.056117
# process_pairs()...
# update_timings()... 2021-06-26 03:59:45.699324
# process_pairs()...
# update_timings()... 2021-06-26 03:59:52.222318
# process_pairs()...
# update_timings()... 2021-06-26 03:59:59.001214
# process_pairs()...
# update_timings()... 2021-06-26 04:00:05.877707
# process_pairs()...
# update_timings()... 2021-06-26 04:00:14.493465
# process_pairs()...
# update_timings()... 2021-06-26 04:00:21.010655
# process_pairs()...
# update_timings()... 2021-06-26 04:00:27.667098
# process_pairs()...
# update_timings()... 2021-06-26 04:00:34.447978
# process_pairs()...
# update_timings()... 2021-06-26 04:00:41.192779
# process_pairs()...
# update_timings()... 2021-06-26 04:00:47.750684
# process_pairs()...
# update_timings()... 2021-06-26 04:00:54.391952
# process_pairs()...
# update_timings()... 2021-06-26 04:01:00.956362
# process_pairs()...
# update_timings()... 2021-06-26 04:01:07.968200
# process_pairs()...
# update_timings()... 2021-06-26 04:01:15.855658
# process_pairs()...
# update_timings()... 2021-06-26 04:01:22.355715
# process_pairs()...
# update_timings()... 2021-06-26 04:01:28.859335
# process_pairs()...
# update_timings()... 2021-06-26 04:01:35.323153
# process_pairs()...
# update_timings()... 2021-06-26 04:01:41.781174
# process_pairs()...
# update_timings()... 2021-06-26 04:01:48.468461
# process_pairs()...
# update_timings()... 2021-06-26 04:01:54.982159
# process_pairs()...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-4c1c224bbfec> in <module>
#      81 if __name__ == "__main__":
#      82     b = TradingBot()
# ---> 83     b.run()
#
# <ipython-input-11-4c1c224bbfec> in run(self)
#      77             print ('process_pairs()...')
#      78             self.process_pairs()
# ---> 79             time.sleep(SLEEP)
#      80
#      81 if __name__ == "__main__":
#
# KeyboardInterrupt:
